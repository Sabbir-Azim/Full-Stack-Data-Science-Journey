# %%
lst = []

lst.append(1,2,3)
lst
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 lst = []
# ----> 3 lst.append(1,2,3)
#       4 lst
#
# TypeError: list.append() takes exactly one argument (3 given)
